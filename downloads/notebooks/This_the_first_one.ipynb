# %% [raw]
# title:  le titre du truc
# slug: le résumé de la chose
# date: 2014-05-12 22:12
# tags: misc
# comments: true

# %% [markdown]
# This is a text that describes that I am doing. First, I launch the `pylab` magic, with inline graphics.

# %%
# %pylab inline
x=randn(100)
plot(x)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
HTML(the_end(theNotebook))
# Out:
#     <small>
#     <p> This post was written as an IPython notebook.  It is available for
#     <a href="http://jfbercher.github.com/jfblog/downloads/notebooks/This_the_first_one.ipynb">download</a> or as a static
#     <a href="http://nbviewer.ipython.org/url/jfbercher.github.com/jfblog/downloads/notebooks/This_the_first_one.ipynb">html</a>.</p>
#     <p></p>
#     <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img
#     alt="Creative Commons License" style="border-width:0"
#     src="http://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span
#     xmlns:dct="http://purl.org/dc/terms/"
#     property="dct:title">jfblog</span> by <a
#     xmlns:cc="http://creativecommons.org/ns#" href="http://jfbercher.github.io/"
#     property="cc:attributionName" rel="cc:attributionURL">J.-F. Bercher</a> is
#     licensed under a <a rel="license"
#     href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons
#     Attribution-ShareAlike 4.0 International License</a>.<br />Based on a work at <a
#     xmlns:dct="http://purl.org/dc/terms/" href="http://jfbercher.github.io/"
#     rel="dct:source">http://jfbercher.github.io/</a>.
